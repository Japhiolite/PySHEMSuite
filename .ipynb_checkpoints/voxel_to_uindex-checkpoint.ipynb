# %%
import numpy as np
import itertools
import collections
import os,sys
import scipy.constants
import fileinput
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick
# %matplotlib inline

# %%
scipy.constants.gas_constant

# %%
with open('TutA_export.vox') as f:
    data = [line.split() for line in f]
    info = dict((var.strip(), float(num.strip())) for var, num in data[0:9])
    if data[9] == ['nodata_value', 'out']:
        print("Warning: nodata_value in line 9.")
        print("There are cells above the surface.")
        print("See TOP_BC_{} for boundary conditions.".format(f.name[:-4]))
        units = list(itertools.chain(*data[10:]))
    else:
        units = list(itertools.chain(*data[9:]))     

#collections.OrderedDict(sorted(info.items(), key=lambda t: t[0]))

# %%
try:
    fT = open("TOP_BC_{}.temp".format(f.name[:-4]),'w')
    fh = open("TOP_BC_{}.head".format(f.name[:-4]),'w')
    fp = open("TOP_BC_{}.pres".format(f.name[:-4]),'w')
except IOError:
    print("Can not open file TOP_BC_{}.temp for writing".format(f.name[:-4]))
    print("Can not open file TOP_BC_{}.head for writing".format(f.name[:-4]))
    print("Can not open file TOP_BC_{}.pres for writing".format(f.name[:-4]))

# %%
p0 = 0.101325
lapserate = -0.0065
t_surf = 288.15
pres = p0 * (1 + lapserate/t_surf * (iz*info['dz'] + info['z0']))**((-scipy.constants.g*0.0289644)/(lapserate*scipy.constants.R))

# %%
try:
    fT = open("TOP_BC_{}.temp".format(f.name[:-4]),'w')
    fh = open("TOP_BC_{}.head".format(f.name[:-4]),'w')
    fp = open("TOP_BC_{}.pres".format(f.name[:-4]),'w')
except IOError:
    print("Can not open file TOP_BC_{}.temp for writing".format(f.name[:-4]))
    print("Can not open file TOP_BC_{}.head for writing".format(f.name[:-4]))
    print("Can not open file TOP_BC_{}.pres for writing".format(f.name[:-4]))
    



nxyz = int(info['nx']*info['ny']*info['nz'])
unui = {}
uindex = 1
count = 1
form = units[0]
uindex_field = []
s = ""
ix = 1
iy = 1
iz = 1
p0 = 0.101325
lapserate = -0.0065
t_surf = 286.15

for i in range(1,nxyz):
    if units[i] not in unui: # if the unit is not in the dictionary, add it
        unui.update({units[i]:uindex})
        uname = units[i]
        uindex += 1 # increase the uindex for shemat
    
    if units[i] == units[i-1]: # count up the units found in the voxel file
        count+=1
    
    else:
        #print("{}*{}".format(count,unui[units[i-1]]))
        # append the units and write it in the format x*y until a new
        # unit is reached
        uindex_field.append("{}*{}".format(count,unui[units[i-1]]))
        s += "{}*{} ".format(count,unui[units[i-1]])
        count = 1
    if i == (nxyz-1):
        #print("{}*{}".format(count,unui[units[i]]))
        # don't forget to include the last unit
        uindex_field.append("{}*{}".format(count,unui[units[i]]))
        s += "{}*{}".format(count,unui[units[i]])
    
    
    if ix < info['nx']:
        ix += 1
    elif iy < info['ny']:
        ix = 1
        iy += 1
    else:
        ix = 1
        iy = 1
        iz += 1
        
    if (units[i] == 'out' and iz < info['nz']) or iz == info['nz']:
        fT.write("{} {} {} {} 0 \n".format(ix,iy,iz, ((iz*info['dz'] + info['z0'])*lapserate + t_surf-273.15)))
        fh.write("{} {} {} {} 0 \n".format(ix,iy,iz, head))
        fp.write("{} {} {} {} 0 \n".format(ix,iy,iz, 0.101325))
    else:
        head = iz*info['dz']
        #pres = p0 * (1 + lapserate/t_surf * (iz*info['dz'] + info['z0']))**((-scipy.constants.g*0.0289644)/(lapserate*scipy.constants.R))
        

un_counts = collections.Counter(units)
fT.close()
fh.close()
fp.close()

# %%
def read_file(filename):
    """
    Open and read a SHEMAT Suite Input File
    **Arguments**:
        - *filename* = string with filename
    **Returns**:
        - List with lines in the file
    """
    try:
        file = open(filename,'r')
    except IOError (nr, string_error):
        print("Cannot open file {}: {} Err# {}".format(filename, string_error, nr))
        print("Please check file name and directory and try again.")
        raise IOError
    # check if number of entries is correct
    filelines = file.readlines()
    file.close()
    return filelines

# %%
f = read_file('model1_input2')

# %%
def sel(self, var_name, value, line=1):
    """
    Set a SHEMAT-Suite variable to a specific value
    **Arguments**:
        -*var_name* = string: name of variable
        -*value* = string or number: value of variable
    """
    for (i,l) in enumerate(self.filelines):
        if var_name in l:
            print(var_name)
            self.filelines[i+line] = str(value) + " \n"

# %%
import test

# %%
fid = test.read_file('model1_input2')

# %%
fid = test.SHEMAT_suite_file('model1_input2')

# %%
fid.read_file('model1_input2')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-baf795379445> in <module>()
# ----> 1 fid.read_file('model1_input2')
#
# TypeError: read_file() takes 1 positional argument but 2 were given

# %%
un_counts = collections.Counter(units)
print(un_counts)
print(sum(un_counts.values()))
print(nxyz)

# %%
info

# %%
p0 * (1 + lapserate/t_surf * (iz*info['dz'] + info['z0']))**((-scipy.constants.g*0.0289644)/(lapserate*scipy.constants.R))

# %%
iz*info['dz'] + info['z0']

# %%
def read_monitor(filename,var_name):
    """
    Routine to read the monitoring points of a transient SHEMAT-Suite
    simulation, returning an array of recorded values
    **Arguments**:
        -*filename*: string: name of monitoring file
        -*var_name*: string or list of strings: name of variables to be loaded
    """
    # change % comments to #
    with fileinput.FileInput(filename, inplace=True, backup='.bak') as file:
        for line in file:
            print(line.replace('%', '#'), end='')
    
    var = {'time':0, 'x':1, 'y':2, 'z':3, 'uindex':4}
                
    fid = np.loadtxt(filename)

# %%
import pandas as p

# %%
with fileinput.FileInput('/home/jni/Dokumente/Shemat_Input/Transient_Models/Conv_CorrLength/r1_50m_hor_corrl/conv_sgsim_E0_monitor_1.dat', inplace=True, backup='.bak') as file:
    for line in file:
        print(line.replace('%', ''), end='')

# %%
dat = p.read_csv('/home/jni/Dokumente/Shemat_Input/Transient_Models/Conv_CorrLength/r1_50m_hor_corrl/conv_sgsim_E0_monitor_1.dat', delim_whitespace=True)

# %%
n_monitor = 0
for i in dat['time,']:
    if i == 0:
        n_monitor += 1
    else:
        break
print("Number of monitoring points is {}.".format(n_monitor))
# Out:
# Number of monitoring points is 8.

# %%
s2y = 365.25*24*3600
s = 3

fig = plt.figure(figsize=[8,8])
ax = fig.add_subplot(111)
ax.plot(dat['time,'][s::n_monitor]/s2y,dat['temp,'][s::n_monitor],'o',color='#33AADD')
ax.set_xlabel("Time in years",fontsize=16)
ax.set_ylabel("Temperature $^\circ$C",fontsize=16, color='#33AADD')
#ax.set_xlim([0, 10])
#ax.set_ylim(ylim)
    
ax1 = ax.twinx()
ax1.plot(dat['time,'][s::n_monitor]/s2y,dat['vz,'][s::n_monitor]*(s2y),'ro')
ax1.set_ylabel("z velocity [m a$^{-1}$]", color='r')
#ax1.set_xlim([0,10])

# %%
import h5p

# %%
r1h5 = h5py.File("/home/jni/Dokumente/Shemat_Input/Transient_Models/Conv_CorrLength/r1_50m_hor_corrl/conv_sgsim_E0_1.h5")

# %%
fx = r1h5["x"][0,0,:]
fz = r1h5["z"][:,0,0]
ft = r1h5["temp"][:,0,:]
fk = r1h5["kz"][:,0,:]
mp = np.array([[400,330,1],
               [400,660,2],
               [800,330,3],
               [800,660,4],
               [1200,330,5],
               [1200,660,6],
               [1600,330,7],
               [1600,660,8]])

# %%
nt
# Out:
# 1

# %%
fig = plt.figure(figsize=[10,12])
ax = fig.add_subplot(111)
ax.contourf(fx,fz,fk,20,cmap='viridis')
ax.plot(mp[:,0],mp[:,1],'ro')
for i,nt in enumerate(mp[:,2]):
    ax.annotate(nt,(mp[i,0],mp[i,1]),fontsize=14,color='white')

# %%
monDmg = np.loadtxt(r"/home/jni/Dokumente/Shemat_Input/Transient_Models/Conv_CorrLength/convection_corrlength_monitor.dat",usecols=[0,1,9,15],skiprows=1)

# %%
tiDmg = monDmg[4::n_monitor,0]
tempDmg = monDmg[4::n_monitor,2]
vzDmg = monDmg[4::n_monitor,3]

# %%
c = 1
fig = plt.figure(figsize=[8,8])
ax = fig.add_subplot(111)
ax.plot(tiDmg[::c]/s2y,tempDmg[::c],'o',color='#33AADD')
ax.set_xlabel("Time in years",fontsize=16)
ax.set_ylabel("Temperature $^\circ$C",fontsize=16, color='#33AADD')
ax.yaxis.set_major_formatter(mtick.FormatStrFormatter('%.3f'))
#ax.set_xlim([0, 8000])
#ax.set_ylim(ylim)
    
ax1 = ax.twinx()
ax1.plot(tiDmg[::c]/s2y,vzDmg[::c]*(s2y),'ro')
ax1.set_ylabel("z velocity [m a$^{-1}$]", color='r')
#ax1.set_xlim([0,8000])
