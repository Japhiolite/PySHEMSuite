# %%
import PySHEMSuite as pys
import PySHEMAT as ps

# %%
pys.create_empty_model(transient=True)
# Out:
# creating empty file
# Write new SHEMAT-Suite Input file: default_SHEMAT_Model
# There is no model info yet!

# %%
ps.create_empty_model()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-3-bde210b3c302> in <module>()
# ----> 1 ps.create_empty_model()
#
# N:\Forschung\GGE0055_MEPRORISK2_gma\MigratedData\git\pyshemsuite\PySHEMAT.pyc in create_empty_model(**kwds)
#    3460         dz = G.delz
#    3461     else:
# -> 3462         dx = kwds['dx']
#    3463         dy = kwds['dy']
#    3464         dz = kwds['dz']
#
# KeyError: 'dx'

# %%
ps_inp = ps.Shemat_file('1a.nml')

# %%
ps_inp.get('GEOLOGY')
# Out:
# '10080*1 \n'

# %%
gobj = pys.SHEMATSuiteFile()
# Out:
# creating empty file

# %%
gobj.get_grid()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-ebca75f1ca5f> in <module>()
# ----> 1 gobj.get_grid()
#
# N:\Forschung\GGE0055_MEPRORISK2_gma\MigratedData\git\pyshemsuite\PySHEMSuite.py in get_grid(self)
#     177
#     178     def get_grid(self):
# --> 179         return self._grid_data
#     180
#     181     def update_extent(self):
#
# AttributeError: SHEMATSuiteFile instance has no attribute '_grid_data'

# %%
reload(pys)
print(gobj)
# Out:
# There is no model info yet!

# %%
inp = pys.SHEMATSuiteFile('model1_input2')

# %%
info, uind = gobj.create_structure_from_voxel('TutA_export.vox')
# Out:
# Warning: nodata_value in line 9.
# There are cells above the surface.
# See TOP_BC_TutA_export for boundary conditions.

# %%
inp.idim
# Out:
# 100

# %%
inp.get("grid").split()
# Out:
# ['100', '1', '100']

# %%
inp.idim[1].split()[2]
# Out:
# '100'

# %%
gobj.set_nxny(10,15)

# %%
gobj.get_nxny()
# Out:
# (10, 15)

# %%
gobj.set_dxdy(50,25)

# %%
import numpy as np
grid_data = np.random.randint(0,10,size= (gobj._nx, gobj._ny))

# %%
gobj.set_grid(grid_data)

# %%
gobj.get_grid()
# Out:
# array([[2, 0, 6, 8, 8, 1, 7, 8, 9, 7],
#        [8, 3, 5, 6, 9, 3, 0, 4, 1, 1],
#        [7, 8, 2, 8, 9, 6, 7, 2, 1, 9],
#        [8, 8, 6, 9, 3, 0, 3, 8, 2, 5],
#        [6, 4, 4, 7, 3, 5, 4, 9, 0, 8],
#        [0, 4, 2, 2, 8, 2, 5, 7, 4, 2],
#        [8, 7, 9, 3, 1, 8, 9, 0, 8, 2],
#        [8, 7, 7, 8, 9, 6, 9, 6, 0, 9],
#        [6, 8, 2, 5, 3, 3, 5, 2, 7, 6],
#        [4, 8, 7, 6, 8, 6, 1, 7, 8, 6]])

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.imshow(gobj.get_grid(), cmap='viridis', interpolation='nearest')

# %%
fi = pys.SHEMATSuiteFile('Input1')

# %%
modInfo, uind = fi.voxel_input('TutA_export.vox')

# %%
reload(pys)

# %%
fi.read_monitor('conv_sgsim_E0_monitor_1.dat')
# Out:
# Seems you still work with Python 2.7.
# You should consider moving to Version 3.x
#               time,  x,   y,  z,"uindex",   i,  j,   k       head,      temp,  \
# 0.000000e+00    395   5  325         6242   40   1  33  1000.00000  48.460187
# 0.000000e+00    395   5  655        12842   40   1  66  1000.00000  36.769535
# 6.000000e+04  3.461593      0      0  1.478146e-08    0  1.796632e-09     0
# 6.000000e+04  6.647794      0      0 -3.663965e-10    0  9.663711e-09     0
# 6.000000e+04  3.461712      0      0 -4.194658e-09    0  5.367955e-09     0
# ...                ...    ...    ...           ...  ...           ...   ...
# 6.216499e+11  6.619018      0      0 -4.854538e-10    0  7.077834e-09     0
# 6.216499e+11  3.451975      0      0  2.830044e-08    0  2.791851e-09     0
# 6.216499e+11  6.627384      0      0 -7.235911e-12    0  1.174401e-09     0
# 6.216499e+11  3.450930      0      0 -2.654756e-09    0  6.727450e-09     0
# 6.216499e+11  6.650616      0      0  2.301312e-09    0 -4.269734e-09     0
# 6.216499e+11  3.460544      0      0  6.357600e-09    0 -1.841363e-10     0
# 6.254285e+11  6.650545      0      0 -8.579516e-09    0 -2.737844e-09     0
# 6.254285e+11  3.470929      0      0  9.201615e-09    0 -5.225072e-09     0
# 6.254285e+11  6.618913      0      0 -4.824498e-10    0  7.113489e-09     0
# 6.254285e+11  3.451975      0      0  2.851356e-08    0  2.798352e-09     0
# 6.254285e+11  6.627551      0      0 -4.023720e-12    0  1.147109e-09     0
# 6.254285e+11  3.450916      0      0 -2.643186e-09    0  6.730981e-09     0
# 6.254285e+11  6.650732      0      0  2.271758e-09    0 -4.290251e-09     0
# 6.254285e+11  3.460542      0      0  6.359125e-09    0 -1.853887e-10     0
# 6.292070e+11  6.650465      0      0 -8.601922e-09    0 -2.727977e-09     0
# 6.292070e+11  3.470935      0      0  9.216374e-09    0 -5.224038e-09     0
# 6.292070e+11  6.618814      0      0 -4.793126e-10    0  7.146217e-09     0
# 6.292070e+11  3.451976      0      0  2.871367e-08    0  2.804375e-09     0
# 6.292070e+11  6.627708      0      0 -9.470142e-13    0  1.121260e-09     0
# 6.292070e+11  3.450903      0      0 -2.632557e-09    0  6.734433e-09     0
# 6.292070e+11  6.650839      0      0  2.243467e-09    0 -4.309236e-09     0
# 6.292070e+11  3.460540      0      0  6.360644e-09    0 -1.865093e-10     0
# 6.311520e+11  6.650424      0      0 -8.613359e-09    0 -2.722945e-09     0
# 6.311520e+11  3.470937      0      0  9.224152e-09    0 -5.223526e-09     0
# 6.311520e+11  6.618765      0      0 -4.776622e-10    0  7.162286e-09     0
# 6.311520e+11  3.451976      0      0  2.881324e-08    0  2.807347e-09     0
# 6.311520e+11  6.627787      0      0  6.007685e-13    0  1.108342e-09     0
# 6.311520e+11  3.450897      0      0 -2.627325e-09    0  6.736187e-09     0
# 6.311520e+11  6.650892      0      0  2.229240e-09    0 -4.318616e-09     0
# 6.311520e+11  3.460539      0      0  6.361424e-09    0 -1.870525e-10     0
#
# [4936 rows x 16 columns]

# %%
import sys

# %%
import fileinput

# %%
if sys.version_info[0] == 3:
    # replace any % comments with
    with fileinput.FileInput(filename, inplace=True, backup='.bak') as fid:
        for line in fid:
            line.replace('%', '')
elif sys.version_info[0] == 2:
    print("Seems you still work with Python 2.7.")
    print("You should consider moving to Version 3.x")
    fid = fileinput.input(files=('conv_sgsim_E0_monitor_1.dat'), inplace=True, backup='.bak')
    for line in fid:
        line.replace('%', '')

# %%
sys.version_info.major
# Out:
# 2
